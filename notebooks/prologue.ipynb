# %% [markdown]
# # Why we are here
#
# ## Lessons learned the hard way
#
# ---
#
# **"Any fool can write code that a computer can understand. Good programmers write code that humans can understand." &mdash; Martin Fowler**
#
# ---
#
# Scientists and researchers often receive little formal training in software development. Yet even modest modelling projects can quickly become complex systems, and early design choices can create long-term maintenance costs.
#
# In the end, **we should all strive to write elegant code**&mdash;code that:
#
# 1. Someone understands on first read
# 2. You revisit six months later and smile, not curse
# 3. New features feel like snapping in a puzzle piece, not defusing a bomb
#
# *(Adapted from a widely shared post on LinkedIn; original source unknown)*
#
# Elegant code is not enough on its own: code must also do the right thing, which means behaviour should be **demonstrably validated through tests**. In scientific software, this matters because results flow directly into publications, models, and downstream analysis. A simple principle helps: **don't believe it unless you can run it**.
#
# Writing elegant code involves many factors, including knowing the tools and strategies available to support good design. Most scientists start with a function-based style: write functions that accept inputs and return results, then combine them with standard control flow. That is perfectly valid, but it is often adopted by default rather than by intentional design choice.
#
# A common pitfall&mdash;especially for those from non-software backgrounds&mdash;is assuming there is one "correct" implementation. In reality, many approaches can be valid, depending on language, domain, and design priorities. The goal of this course is to introduce guiding principles and practical patterns you can apply to your own projects, whether you are building a quick prototype or something lasting.
#
# My personal mantra is to assume code will be *lasting*. That mindset encourages care, and it also means managing your maintenance budget: write less code, and **learn to enjoy removing code that no longer serves a purpose**. Every line deleted is one you never have to maintain.
#
# This course is designed to cultivate software developers who not only write code, but also break down complex problems into coherent, domain-aware components. AI tools are actively encouraged, but they cannot replace critical thinking, domain expertise, or architectural judgement. As Hunter Muse put it:
#
# > **"AI can generate code, but it can't compensate for not understanding the problem you're trying to solve or the questions you don't know how to ask." &mdash; Hunter Muse**
#
# He also highlighted systems thinking: the ability to understand how components interact within a larger software system. That skill will remain essential.
#
# On a personal note, my motivation for assembling this course comes from hard-earned experience in software projects. Good software design has long been undervalued in academia, even though robust, maintainable software is essential for reproducible and transparent science. As attitudes begin to shift, this is a timely chance to raise expectations and give researchers practical tools to treat software as a first-class scientific instrument.
#
# ## Course structure
#
# There are countless resources online for learning software development, and you are encouraged to make full use of them. This course aims to distinguish itself in two key ways:
#
# 1. **Top-down learning approach** - Core ideas are introduced through practical code snippets first, with deeper explanations later.
#
# 1. **Tailored for scientists and engineers** – The material focuses on essential principles, common pitfalls, and a pragmatic "survivor's guide" to writing good scientific code.
#
# The course adopts terminology commonly used by computer scientists, because that aligns with most external resources. Terms like classes, instances, objects, and methods can feel heavy at first, but becoming fluent in this language makes documentation easier to use and communication with collaborators much smoother.
#
# The course is divided into **main content**, **bonus**, and **appendices**. The main content covers foundational principles; the appendices provide additional reading and practical setup guides, such as IDE configuration. This keeps the core material stable while allowing faster-changing tool guidance&mdash;including AI-assisted workflows&mdash;to evolve over time.
#
# Using AI tools with simple prompts is an excellent way to generate templates, debug unfamiliar code, and accelerate learning. Think of AI as a powerful assistant for rapid iteration. For that reason, this course does not over-emphasise boilerplate code examples; instead, the **focus is on core concepts, so you can understand, critique, and adapt AI-generated code** to your own goals.
#
# Python is used as the working language because it remains broadly applicable across academia and industry. Its flexibility makes it well-suited for demonstrating the concepts we cover. That said, **the underlying principles are largely language-agnostic**. Some languages (for example, early Fortran) have limited object-oriented support, while others (such as Rust) deliberately constrain traditional class-style patterns to encourage safer design.
#
# The course materials are open source, and feedback is warmly welcomed. Treat this course as a living document that evolves with best practice. Likewise, no software project is ever truly complete, including this one. Continuous iteration is where most of the meaningful learning happens. I extend my sincere thanks to the friends and colleagues whose insights have helped shape this course.
